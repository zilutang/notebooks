# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-1, 1, 50)
y = 2 * x + 1
plt.plot(x, y)
plt.show()

y = x ** 2
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(-3, 3, 50)
y1 = 2 * x + 1
y2 = x ** 2

plt.figure(num=1, figsize=(8, 5))
plt.plot(x, y1)
plt.show()

plt.figure()
plt.plot(x, y2)
plt.show()

plt.figure()


plt.xlim((-1, 2))
plt.ylim((-2, 3))

plt.xlabel('I am x')
plt.ylabel('I am y')

new_ticks = np.linspace(-1, 2, 5)
print new_ticks
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3],
            ['really bad', '$bad\ \alpha$', 'normal', r'$good\ \alpha$', '$really\ good$'])

ax = plt.gca() # 获取边框线
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none') # 去掉右侧和上边框

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data', -1)) # x轴设置在y为-1的位置
ax.spines['left'].set_position(('data', 0))

#设置legend （图例）
plt.plot(x, y2, label='up')
plt.plot(x, y1, linewidth=1.0, linestyle='--', label='down')
plt.legend(labels=['aaa', 'bbb'], loc='center right')


plt.show()
# Out:
# [-1.   -0.25  0.5   1.25  2.  ]

# %% [markdown]
# # 添加注解 Annotation

# %%
x = np.linspace(-3, 3, 50)
y = 2 * x + 1

plt.figure(num=1, figsize=(8, 5))
plt.plot(x, y,)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

x0 = 1
y0 = 2 * x0 + 1

plt.scatter(x0, y0, s=50, color='b') # 画出点图, s:大小
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

plt.annotate(r'$2x+1=%s$' %y0, xy=(x0, y0), xycoords='data', xytext=(+1.5, 1), #textcoords='offset point',
            fontsize=16, arrowprops=dict(arrowstyle='->', connectionstyle='arc3, rad=.2'))

plt.text(-3.7, 3, r'$This\ is\ the\ some\ test.\ \mu\ \sigma_i\ \alpha_t$', fontdict={'size':16, 'color':'r'})
