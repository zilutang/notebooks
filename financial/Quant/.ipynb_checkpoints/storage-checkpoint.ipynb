# %%
import tushare as ts
import numpy as np
import pandas as pd
import h5py
import urllib2

# %%
d = ts.get_tick_data('600848',date='2015-01-09')

# %%
len(d)
h5.close()
h5 = pd.HDFStore('./data/test2.h5','w')
h5['data'] = d
h5.close()

# %%
h5 = pd.HDFStore('./data/test2.h5','r')
e = h5['data']
h5.close()

# %%
f = h5py.File('./data/test2.h5', 'r')
f
# Out:
# <HDF5 file "test2.h5" (mode r)>

# %%
f2017 = pd.read_excel('./data/frameleftT1-2017.xlsx')
f2017
# Out:
#       opendate   name     h1     h2     h3     h4     h5      h6     h7  \
# 0     sh600000   浦发银行    NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 1     sh600001   邯郸钢铁     --    NaN    NaN    NaN    NaN     NaN    NaN
# 2     sh600003  ST东北高     --    NaN    NaN    NaN    NaN     NaN    NaN
# 3     sh600004   白云机场 -12.76   -2.2  -1.06  -3.71  -12.3  -10.31   0.26
# 4     sh600005   武钢股份  -2.64  -2.11  -12.5  -2.12  24.24   -4.54  -8.15
# 5     sh600006   东风汽车  -3.54 -15.58  -1.03  -9.83  18.15   31.45   2.74
# 6     sh600007   中国国贸 -10.25 -18.72  -0.92  -0.14 -16.62  -22.86  14.24
# 7     sh600008   首创股份   9.06   1.54  -0.69   5.58   1.87   -11.2  -7.01
# 8     sh600009   上海机场 -15.55  13.01  -3.06   -4.7  -7.29  -23.68  21.98
# 9     sh600010   包钢股份  -2.25  -3.65  -0.24 -11.52 -17.47   36.44  17.43
# 10    sh600011   华能国际 -32.45  32.38   8.41     --    NaN     NaN    NaN
# 11    sh600012   皖通高速     --    NaN    NaN    NaN    NaN     NaN    NaN
# ...

# %%
h52017 = pd.HDFStore('./data/f2017a.h5', 'w')
h52017['data'] = f2017
h52017.close()
# Out:
# K:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:2: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   from IPython.kernel.zmq import kernelapp as app
# K:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:2: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   from IPython.kernel.zmq import kernelapp as app
# K:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3035: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->[u'opendate', u'name', u'h1', u'h2', u'h3', u'h4', u'h5', u'h6', u'h7', u'h8', u'h9', u'h10', u'hjcg', datetime.datetime(2017, 9, 1, 0, 0)]]
#
# ...

# %%
h5 = pd.HDFStore('./data/f2017a.h5','r')
e = h5['data']
h5.close()

# %%
url = r'http://table.finance.yahoo.com/table.csv?s=600099.ss&b=1'
frameresult = pd.read_csv(url)
frameresult
# Out:
#             Date      Open      High       Low     Close    Volume  Adj Close
# 0     2017-01-13  17.98000  18.74000  17.85000  17.94000  13991600   17.94000
# 1     2017-01-12  17.91000  18.46000  17.70000  17.84000  16371100   17.84000
# 2     2017-01-11  18.72000  18.82000  17.52000  17.68000  19666300   17.68000
# 3     2017-01-10  18.90000  19.47000  18.52000  19.12000  20335800   19.12000
# 4     2017-01-09  18.73000  19.60000  18.23000  18.99000  23383700   18.99000
# 5     2017-01-06  19.29000  20.08000  18.18000  19.03000  25896000   19.03000
# 6     2017-01-05  19.60000  19.90000  18.90000  19.52000  29013400   19.52000
# 7     2017-01-04  20.86000  21.02000  18.74000  19.95000  51296100   19.95000
# 8     2017-01-03  18.99000  20.82000  18.85000  20.82000  41564800   20.82000
# 9     2017-01-02  18.93000  18.93000  18.93000  18.93000         0   18.93000
# 10    2016-12-30  19.70000  20.67000  18.80000  18.93000  35981200   18.93000
# ...

# %%
url1 = r'http://vip.stock.finance.sina.com.cn/quotes_service/api/json_v2.php/MoneyFlow.ssl_bkzj_ssggzj?page=1&num=20&sort=r0_net&asc=0&bankuai=&shichang='
frameresult1 = pd.read_json(url)
frameresult1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-c9a37c78699f> in <module>()
#       1 url1 = r'http://vip.stock.finance.sina.com.cn/quotes_service/api/json_v2.php/MoneyFlow.ssl_bkzj_ssggzj?page=1&num=20&sort=r0_net&asc=0&bankuai=&shichang='
# ----> 2 frameresult1 = pd.read_json(url)
#       3 frameresult1
#
# K:\Anaconda\lib\site-packages\pandas\io\json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# K:\Anaconda\lib\site-packages\pandas\io\json.pyc in parse(self)
#     277
#     278         else:
# ...

# %%
import ystockquote
print ystockquote.get_price('GOOG')
# Out:
# 807.88
