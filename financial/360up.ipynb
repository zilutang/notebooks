# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data/360UP.txt', sep = '\t', names = ['l20', 'rate', 'up'], nrows=200)
print data.head()
data.info()
# Out:
#    l20    rate     up
# 0   13   9.084  1.552
# 1   19   6.073  1.452
# 2   11  10.360  2.137
# 3   15   7.417  1.289
# 4   15   7.351  1.252
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
# l20     200 non-null int64
# rate    200 non-null float64
# up      200 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 4.8 KB

# %%
print data[data.l20 < 5]
sns.pairplot(data[data.l20 < 5], x_vars = ['l20'], y_vars = 'up', size = 7, aspect=2)
# Out:
#      l20     rate     up
# 27     1   90.000  1.718
# 44     0  720.000  1.371
# 57     0  630.000  1.317
# 81     1   53.636  1.246
# 84     0  590.000  1.340
# 96     1   51.818  1.119
# 109    3   18.065  1.195
# 122    0  550.000  1.171
# 124    4   13.415  1.244
# 129    0  550.000  1.444
# 143    3   17.097  1.230
# 144    2   25.238  1.076
# 146    4   12.927  1.001
# 149    1   48.182  1.331
# 158    0  530.000  1.064
# 159    3   17.097  1.095
# 161    4   12.927  1.129
# 166    3   17.097  1.117
# 167    3   17.097  1.387
# 168    4   12.927  1.237
# 174    1   47.273  1.130
# 177    3   16.774  1.216
# 178    0  520.000  1.331
# 179    2   24.762  1.093
# 189    3   16.774  1.083
# 194    1   47.273  1.172
# 195    4   12.683  1.254
# 196    0  510.000  1.092
# 197    4   12.439  0.993
# 198    0  510.000  1.136

# %%
data = pd.read_csv('data/360UP.txt', sep = '\t', names = ['l20', 'rate', 'up'])
sns.pairplot(data[data.l20 < 2], x_vars=['l20'], y_vars='up', size=7, aspect=2, kind='reg')
